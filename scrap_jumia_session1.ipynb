# %% [markdown]
# <a href="https://colab.research.google.com/github/rimoucha2022/rimoucha/blob/main/scrap_jumia_session1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Formation Machine Learning: Collecte de données par le scrapping sur Jumia

# %%
#import requests
import csv
import re
import codecs
#import ssl
#import time
from bs4 import BeautifulSoup as soup
from urllib.request import Request, urlopen
#from csv import writer

# %%
#creation fichier csv et ouvrir
f= codecs.open('jumia.csv', 'wb', encoding= 'utf-8') 
writer = csv.writer(f)
# ecrire dans le csv des entretes à partir des infos à collecter à partir du site
writer.writerow(["description","remise", "prix","ancien_prix"])
for i in range(1,51): 
    print("Numéro de la page à scrapper:",i)
    #req = Request('https://www.jumia.com.tn/telephone-tablettes/?page={}'.format(i), headers={'User-Agent': 'Mozilla/5.0'})
    req = Request('https://www.jumia.com.tn/electronique/?page={}#catalog-listing'.format(i), headers={'User-Agent': 'Mozilla/5.0'})   
    webpage = urlopen(req).read()
    page_soup=soup(webpage,'html.parser')
    page_soup.text
    #print(page_soup)
    posts=page_soup.findAll('div',class_='info')
    print("Le nombre d'item est:",len(posts))
    #print(posts)
    print('******************************************')
    for post in posts:     
        print(post)
        description=post.findAll('h3', class_='name')
        if not description:
            description2 = ""
        else:
            description1=description[0].text
            description2 = re.sub('\s+',' ',description1)
            print(description2)
        
        remise=post.findAll('div', class_='tag _dsct _sm')
        if not remise:
            remise2=""
        else:
            remise1=remise[0].text
            remise2 = re.sub('\s+',' ',remise1)
            print(remise2)
        
        price=post.findAll('div', class_='prc')
        if not price:
            price2=""
        else:
            price1=price[0].text
            price2 = re.sub('\s+',' ',price1)
            print(price2)        
        old_price=post.findAll('div', class_='old')
        if not old_price:
            old_price=""
        else:
            old_price1=old_price[0].text
            old_price2 = re.sub('\s+',' ',old_price1)
            print(old_price2)
        if price2=="" and description2 == "":
            print("bonjour")
        else:
            writer.writerow([description2, remise2, price2,old_price2])
        print("ok")
    print('*****************************************')
    print('*****************************************')
    print('*****************************************')
    print('*****************************************')
f.close()
# Out:
# Numéro de la page à scrapper: 1
# Le nombre d'item est: 48
# ******************************************
# <div class="info"><h3 class="name">Support Mural TV 14"-42"  - Mobile - CP302 - Noir</h3><div class="prc">28.00 TND</div><div class="s-prc-w"><div class="old">49.00 TND</div><div class="tag _dsct _sm">43%</div></div><p class="mpg" data-prc="28.00 TND" data-tot="5">offres à partir de</p><div class="rev"><div class="stars _s">4.2 out of 5<div class="in" style="width:84%"></div></div>(43)</div></div>
# Support Mural TV 14"-42" - Mobile - CP302 - Noir
# 43%
# 28.00 TND
# 49.00 TND
# ok
# <div class="info"><h3 class="name">Câble Jack Mâle Femelle - 3 M - Noir</h3><div class="prc">8.90 TND</div><div class="s-prc-w"><div class="old">11.00 TND</div><div class="tag _dsct _sm">19%</div></div><p class="mpg" data-prc="8.90 TND" data-tot="7">offres à partir de</p><div class="rev"><div class="stars _s">4.1 out of 5<div class="in" style="width:81.99999999999999%"></div></div>(13)</div></div>
# Câble Jack Mâle Femelle - 3 M - Noir
# 19%
# 8.90 TND
# 11.00 TND
# ok
# <div class="info"><h3 class="name">Vega Téléviseur 50" - Smart TV UHD - F50F1UBG - Garantie 3 Ans</h3><div class="prc">1,495.00 TND</div><div class="s-prc-w"><div class="old">1,799.00 TND</div><div class="tag _dsct _sm">17%</div></div><p class="mpg" data-prc="1,490.00 TND" data-tot="2">offres à partir de</p><div class="rev"><div class="stars _s">5 out of 5<div class="in" style="width:100%"></div></div>(2)</div><svg aria-label="Livraison rapide" class="ic xprss" height="10" viewbox="0 0 114 12" width="94"><use xlink:href="https://www.jumia.com.tn/assets_he/images/i-shop-jumia.c8de1c55.svg#express"></use></svg><p class="shipp">Eligible à la livraison gratuite avec Jumia Express Ou Jumia Prime.</p></div>
# Vega Téléviseur 50" - Smart TV UHD - F50F1UBG - Garantie 3 Ans
# 17%
# 1,495.00 TND
# 1,799.00 TND
# ok
# <div class="info"><div class="tag _mall _sm">Boutique Officielle</div><h3 class="name">XIAOMI Mi Home Security Camera 360°1080P - Blanc - Garantie 1 An</h3><div class="prc">84.90 TND</div><div class="s-prc-w"><div class="old">99.00 TND</div><div class="tag _dsct _sm">14%</div></div><div class="rev"><div class="stars _s">4.4 out of 5<div class="in" style="width:88.00000000000001%"></div></div>(124)</div><svg aria-label="Livraison rapide" class="ic xprss" height="10" viewbox="0 0 114 12" width="94"><use xlink:href="https://www.jumia.com.tn/assets_he/images/i-shop-jumia.c8de1c55.svg#express"></use></svg><p class="shipp">Eligible à la livraison gratuite avec Jumia Express Ou Jumia Prime.</p></div>
# XIAOMI Mi Home Security Camera 360°1080P - Blanc - Garantie 1 An
# 14%
# 84.90 TND
# 99.00 TND
# ok
# <div class="info"><h3 class="name">Anycast Récepteur Dongle TV AnyCast M4 Plus 1080P -  Wifi - Noir</h3><div class="prc">42.00 TND</div><div class="s-prc-w"><div class="old">72.00 TND</div><div class="tag _dsct _sm">42%</div></div><p class="mpg" data-prc="42.00 TND" data-tot="5">offres à partir de</p><div class="rev"><div class="stars _s">3.9 out of 5<div class="in" style="width:78%"></div></div>(58)</div></div>
# Anycast Récepteur Dongle TV AnyCast M4 Plus 1080P - Wifi - Noir
# 42%
# 42.00 TND
# 72.00 TND
# ok
# <div class="info"><h3 class="name">Macro Haut Parleur 263T USB 2.0 - Rouge</h3><div class="prc">15.00 TND</div><div class="s-prc-w"><div class="old">20.00 TND</div><div class="tag _dsct _sm">25%</div></div><div class="rev"><div class="stars _s">3.3 out of 5<div class="in" style="width:66%"></div></div>(4)</div></div>
# Macro Haut Parleur 263T USB 2.0 - Rouge
# 25%
# 15.00 TND
# 20.00 TND
# ok
# <div class="info"><h3 class="name">Splitter HDMI Full 1 X 4 sortie - gris</h3><div class="prc">60.00 TND</div><div class="s-prc-w"><div class="old">100.00 TND</div><div class="tag _dsct _sm">40%</div></div><p class="mpg" data-prc="60.00 TND" data-tot="2">offres à partir de</p><div class="rev"><div class="stars _s">3.8 out of 5<div class="in" style="width:76%"></div></div>(6)</div></div>
# Splitter HDMI Full 1 X 4 sortie - gris
# 40%
# 60.00 TND
# 100.00 TND
# ok
# <div class="info"><h3 class="name">Vega Téléviseur 42" - Récepteur intégré - FULL HD - L42F1FBE - Garantie 3 Ans</h3><div class="prc">845.00 TND</div><div class="s-prc-w"><div class="old">999.00 TND</div><div class="tag _dsct _sm">15%</div></div><p class="mpg" data-prc="845.00 TND" data-tot="4">offres à partir de</p><div class="rev"><div class="stars _s">4.3 out of 5<div class="in" style="width:86%"></div></div>(68)</div><svg aria-label="Livraison rapide" class="ic xprss" height="10" viewbox="0 0 114 12" width="94"><use xlink:href="https://www.jumia.com.tn/assets_he/images/i-shop-jumia.c8de1c55.svg#express"></use></svg><p class="shipp">Eligible à la livraison gratuite avec Jumia Express Ou Jumia Prime.</p></div>
# Vega Téléviseur 42" - Récepteur intégré - FULL HD - L42F1FBE - Garantie 3 Ans
# 15%
# 845.00 TND
# 999.00 TND
# ok
# <div class="info"><h3 class="name">Speaker- Bluetooth -  Avec Batterie - micro -Radio Fm</h3><div class="prc">95.00 TND</div><div class="s-prc-w"><div class="old">169.00 TND</div><div class="tag _dsct _sm">44%</div></div><p class="mpg" data-prc="95.00 TND" data-tot="3">offres à partir de</p><div class="rev"><div class="stars _s">5 out of 5<div class="in" style="width:100%"></div></div>(1)</div></div>
# Speaker- Bluetooth - Avec Batterie - micro -Radio Fm
# 44%
# 95.00 TND
# 169.00 TND
# ok
# <div class="info"><h3 class="name">XIAOMI Camera De Surveillance 360° 1080P Wifi - Blanc</h3><div class="prc">84.00 TND</div><div class="s-prc-w"><div class="old">199.00 TND</div><div class="tag _dsct _sm">58%</div></div><p class="mpg" data-prc="84.00 TND" data-tot="3">offres à partir de</p><div class="rev"><div class="stars _s">4.2 out of 5<div class="in" style="width:84%"></div></div>(174)</div><svg aria-label="Livraison rapide" class="ic xprss" height="10" viewbox="0 0 114 12" width="94"><use xlink:href="https://www.jumia.com.tn/assets_he/images/i-shop-jumia.c8de1c55.svg#express"></use></svg><p class="shipp">Eligible à la livraison gratuite avec Jumia Express Ou Jumia Prime.</p></div>
# XIAOMI Camera De Surveillance 360° 1080P Wifi - Blanc
# 58%
# 84.00 TND
# 199.00 TND
# ok
# <div class="info"><h3 class="name">Caméra de surveillance - 3 Antennes - HD Infrarouge - IP wifi</h3><div class="prc">105.00 TND</div><div class="s-prc-w"><div class="old">199.00 TND</div><div class="tag _dsct _sm">47%</div></div><p class="mpg" data-prc="105.00 TND" data-tot="2">offres à partir de</p></div>
# Caméra de surveillance - 3 Antennes - HD Infrarouge - IP wifi
# 47%
# 105.00 TND
# 199.00 TND
# ok
# <div class="info"><h3 class="name">STAR ONE Plaque De Cuisson À Gaz - 4 Feux - Inox - Avec brûleur à double tête - Garantie 1 an</h3><div class="prc">179.00 TND</div><div class="s-prc-w"><div class="old">215.00 TND</div><div class="tag _dsct _sm">17%</div></div><div class="rev"><div class="stars _s">5 out of 5<div class="in" style="width:100%"></div></div>(1)</div><svg aria-label="Livraison rapide" class="ic xprss" height="10" viewbox="0 0 114 12" width="94"><use xlink:href="https://www.jumia.com.tn/assets_he/images/i-shop-jumia.c8de1c55.svg#express"></use></svg><p class="shipp">Eligible à la livraison gratuite avec Jumia Express Ou Jumia Prime.</p></div>
# STAR ONE Plaque De Cuisson À Gaz - 4 Feux - Inox - Avec brûleur à double tête - Garantie 1 an
# 17%
# 179.00 TND
# 215.00 TND
# ok
# <div class="info"><h3 class="name">XIAOMI Camera De Surveillance 360° 2K - Wifi - Blanc</h3><div class="prc">115.00 TND</div><div class="s-prc-w"><div class="old">199.00 TND</div><div class="tag _dsct _sm">42%</div></div><div class="rev"><div class="stars _s">4.5 out of 5<div class="in" style="width:90%"></div></div>(8)</div><svg aria-label="Livraison rapide" class="ic xprss" height="10" viewbox="0 0 114 12" width="94"><use xlink:href="https://www.jumia.com.tn/assets_he/images/i-shop-jumia.c8de1c55.svg#express"></use></svg><p class="shipp">Eligible à la livraison gratuite avec Jumia Express Ou Jumia Prime.</p></div>
# XIAOMI Camera De Surveillance 360° 2K - Wifi - Blanc
# 42%
# 115.00 TND
# 199.00 TND
# ok
# <div class="info"><h3 class="name">Starsat Clé wifi - USB Avec Antenne - Couleur Noir</h3><div class="prc">11.12 TND</div><div class="s-prc-w"><div class="old">19.00 TND</div><div class="tag _dsct _sm">41%</div></div><p class="mpg" data-prc="11.12 TND" data-tot="3">offres à partir de</p><div class="rev"><div class="stars _s">4.1 out of 5<div class="in" style="width:81.99999999999999%"></div></div>(31)</div></div>
# Starsat Clé wifi - USB Avec Antenne - Couleur Noir
# 41%
# 11.12 TND
# 19.00 TND
# ok
# <div class="info"><h3 class="name">SAMBOX Box Android - 6K-2G RAM/16G ROM</h3><div class="prc">119.00 TND</div><div class="rev"><div class="stars _s">5 out of 5<div class="in" style="width:100%"></div></div>(1)</div></div>
# SAMBOX Box Android - 6K-2G RAM/16G ROM
# 119.00 TND
# ok
# <div class="info"><h3 class="name">Camera WiFi Dôme Motorisée Extérieure - suivi mouvement -</h3><div class="prc">259.00 TND</div><div class="s-prc-w"><div class="old">299.00 TND</div><div class="tag _dsct _sm">13%</div></div><div class="rev"><div class="stars _s">4.5 out of 5<div class="in" style="width:90%"></div></div>(2)</div></div>
# Camera WiFi Dôme Motorisée Extérieure - suivi mouvement -
# 13%
# 259.00 TND
# 299.00 TND
# ok
# <div class="info"><div class="tag _mall _sm">Boutique Officielle</div><h3 class="name">Vega Smart TV HD - 32"  - Android - L32F1HBG - Garantie 3 Ans +  Support murale</h3><div class="prc">729.00 TND</div><div class="s-prc-w"><div class="old">899.00 TND</div><div class="tag _dsct _sm">19%</div></div><p class="mpg" data-prc="729.00 TND" data-tot="3">offres à partir de</p><div class="rev"><div class="stars _s">4.3 out of 5<div class="in" style="width:86%"></div></div>(3)</div><svg aria-label="Livraison rapide" class="ic xprss" height="10" viewbox="0 0 114 12" width="94"><use xlink:href="https://www.jumia.com.tn/assets_he/images/i-shop-jumia.c8de1c55.svg#express"></use></svg><p class="shipp">Eligible à la livraison gratuite avec Jumia Express Ou Jumia Prime.</p></div>
# Vega Smart TV HD - 32" - Android - L32F1HBG - Garantie 3 Ans + Support murale
# 19%
# 729.00 TND
# 899.00 TND
# ok
# <div class="info"><h3 class="name">Radio Smart - Rechargeable - MP3 / USB / gold</h3><div class="prc">38.00 TND</div><div class="s-prc-w"><div class="old">75.00 TND</div><div class="tag _dsct _sm">49%</div></div><div class="rev"><div class="stars _s">3.7 out of 5<div class="in" style="width:74%"></div></div>(9)</div></div>
# Radio Smart - Rechargeable - MP3 / USB / gold
# 49%
# 38.00 TND
# 75.00 TND
# ok
# <div class="info"><div class="tag _mall _sm">Boutique Officielle</div><h3 class="name">XIAOMI Mi 360° Home Security Camera 2K Pro	- Garantie 1 An</h3><div class="prc">149.00 TND</div><div class="rev"><div class="stars _s">4.7 out of 5<div class="in" style="width:94%"></div></div>(9)</div><svg aria-label="Livraison rapide" class="ic xprss" height="10" viewbox="0 0 114 12" width="94"><use xlink:href="https://www.jumia.com.tn/assets_he/images/i-shop-jumia.c8de1c55.svg#express"></use></svg><p class="shipp">Eligible à la livraison gratuite avec Jumia Express Ou Jumia Prime.</p></div>
# XIAOMI Mi 360° Home Security Camera 2K Pro - Garantie 1 An
# 149.00 TND
# ok
# <div class="info"><h3 class="name">Anycast M9 PLUS - WiFi HDMI - Display - TV Dongle - Noir</h3><div class="prc">39.00 TND</div><div class="s-prc-w"><div class="old">99.00 TND</div><div class="tag _dsct _sm">61%</div></div><p class="mpg" data-prc="39.00 TND" data-tot="2">offres à partir de</p><div class="rev"><div class="stars _s">3.1 out of 5<div class="in" style="width:62%"></div></div>(40)</div></div>
# Anycast M9 PLUS - WiFi HDMI - Display - TV Dongle - Noir
# 61%
# 39.00 TND
# 99.00 TND
# ok
# <div class="info"><h3 class="name">Adaptateur casque/micro sur port Jack 3.5 mm</h3><div class="prc">16.00 TND</div><div class="s-prc-w"><div class="old">29.00 TND</div><div class="tag _dsct _sm">45%</div></div><div class="rev"><div class="stars _s">4.6 out of 5<div class="in" style="width:91.99999999999999%"></div></div>(8)</div></div>
# Adaptateur casque/micro sur port Jack 3.5 mm
# 45%
# 16.00 TND
# 29.00 TND
# ok
# <div class="info"><h3 class="name">Caméra extérieur wifi - 360° -</h3><div class="prc">229.00 TND</div><div class="s-prc-w"><div class="old">279.00 TND</div><div class="tag _dsct _sm">18%</div></div><div class="rev"><div class="stars _s">3.9 out of 5<div class="in" style="width:78%"></div></div>(17)</div></div>
# Caméra extérieur wifi - 360° -
# 18%
# 229.00 TND
# 279.00 TND
# ok
# <div class="info"><h3 class="name">WAXIBA Radio Smart - Rechargeable - MP3 / USB / noire</h3><div class="prc">35.00 TND</div><div class="s-prc-w"><div class="old">80.00 TND</div><div class="tag _dsct _sm">56%</div></div><div class="rev"><div class="stars _s">2.5 out of 5<div class="in" style="width:50%"></div></div>(2)</div></div>
# WAXIBA Radio Smart - Rechargeable - MP3 / USB / noire
# 56%
# 35.00 TND
# 80.00 TND
# ok
# <div class="info"><h3 class="name">Telefunken Téléviseur 43" LED - Full HD - Smart - Android</h3><div class="prc">1,150.00 TND</div><div class="s-prc-w"><div class="old">1,369.00 TND</div><div class="tag _dsct _sm">16%</div></div></div>
# Telefunken Téléviseur 43" LED - Full HD - Smart - Android
# 16%
# 1,150.00 TND
# 1,369.00 TND
# ok
# <div class="info"><h3 class="name">TPLink Prise connectée P100</h3><div class="prc">69.00 TND</div><div class="rev"><div class="stars _s">5 out of 5<div class="in" style="width:100%"></div></div>(2)</div></div>
# TPLink Prise connectée P100
# 69.00 TND
# ok
# <div class="info"><h3 class="name">Joc Mini Radio FM numérique portable - jack/ Carte SD/ USB Flash</h3><div class="prc">27.90 TND</div><div class="s-prc-w"><div class="old">39.00 TND</div><div class="tag _dsct _sm">28%</div></div><p class="mpg" data-prc="27.90 TND" data-tot="2">offres à partir de</p><div class="rev"><div class="stars _s">4.3 out of 5<div class="in" style="width:86%"></div></div>(13)</div></div>
# Joc Mini Radio FM numérique portable - jack/ Carte SD/ USB Flash
# 28%
# 27.90 TND
# 39.00 TND
# ok
# <div class="info"><h3 class="name">STAR ONE Plaque De Cuisson 4Feux Verre - Garantie 1 an</h3><div class="prc">188.00 TND</div><div class="s-prc-w"><div class="old">235.00 TND</div><div class="tag _dsct _sm">20%</div></div><div class="rev"><div class="stars _s">1 out of 5<div class="in" style="width:20%"></div></div>(1)</div><svg aria-label="Livraison rapide" class="ic xprss" height="10" viewbox="0 0 114 12" width="94"><use xlink:href="https://www.jumia.com.tn/assets_he/images/i-shop-jumia.c8de1c55.svg#express"></use></svg><p class="shipp">Eligible à la livraison gratuite avec Jumia Express Ou Jumia Prime.</p></div>
# STAR ONE Plaque De Cuisson 4Feux Verre - Garantie 1 an
# 20%
# 188.00 TND
# 235.00 TND
# ok
# <div class="info"><h3 class="name">Joc Fm Radio Radio FM MP3 - Rouge - 55 Channel - Garantie 1 an</h3><div class="prc">23.00 TND</div><div class="s-prc-w"><div class="old">45.00 TND</div><div class="tag _dsct _sm">49%</div></div><div class="rev"><div class="stars _s">5 out of 5<div class="in" style="width:100%"></div></div>(1)</div></div>
# Joc Fm Radio Radio FM MP3 - Rouge - 55 Channel - Garantie 1 an
# 49%
# 23.00 TND
# 45.00 TND
# ok
# <div class="info"><div class="tag _mall _sm">Boutique Officielle</div><h3 class="name">XIAOMI Mi Home Security Camera 360° - 1080P - Blanc - Garantie 1 an</h3><div class="prc">90.00 TND</div><div class="rev"><div class="stars _s">3 out of 5<div class="in" style="width:60%"></div></div>(1)</div><svg aria-label="Livraison rapide" class="ic xprss" height="10" viewbox="0 0 114 12" width="94"><use xlink:href="https://www.jumia.com.tn/assets_he/images/i-shop-jumia.c8de1c55.svg#express"></use></svg><p class="shipp">Eligible à la livraison gratuite avec Jumia Express Ou Jumia Prime.</p></div>
# XIAOMI Mi Home Security Camera 360° - 1080P - Blanc - Garantie 1 an
# 90.00 TND
# ok
# <div class="info"><h3 class="name">Kisonli Haut-parleur portable - KK02 - Bluetooth - Noir</h3><div class="prc">27.90 TND</div><div class="s-prc-w"><div class="old">69.00 TND</div><div class="tag _dsct _sm">60%</div></div><p class="mpg" data-prc="27.90 TND" data-tot="2">offres à partir de</p><div class="rev"><div class="stars _s">3.3 out of 5<div class="in" style="width:66%"></div></div>(124)</div></div>
# Kisonli Haut-parleur portable - KK02 - Bluetooth - Noir
# 60%
# 27.90 TND
# 69.00 TND
# ok
# <div class="info"><h3 class="name">Telefunken TV 32" - D6 - LED HD Avec Récepteur Intégré - Garantie 3 ans</h3><div class="prc">589.00 TND</div><div class="s-prc-w"><div class="old">639.00 TND</div><div class="tag _dsct _sm">8%</div></div><p class="mpg" data-prc="589.00 TND" data-tot="2">offres à partir de</p><div class="rev"><div class="stars _s">4 out of 5<div class="in" style="width:80%"></div></div>(5)</div></div>
# Telefunken TV 32" - D6 - LED HD Avec Récepteur Intégré - Garantie 3 ans
# 8%
# 589.00 TND
# 639.00 TND
# ok
# <div class="info"><h3 class="name">Caméra de surveillance - IP Wi-Fi - HD Infrarouge - 3 Antennes</h3><div class="prc">124.00 TND</div><div class="s-prc-w"><div class="old">179.00 TND</div><div class="tag _dsct _sm">31%</div></div><p class="mpg" data-prc="124.00 TND" data-tot="2">offres à partir de</p><div class="rev"><div class="stars _s">4 out of 5<div class="in" style="width:80%"></div></div>(227)</div></div>
# Caméra de surveillance - IP Wi-Fi - HD Infrarouge - 3 Antennes
# 31%
# 124.00 TND
# 179.00 TND
# ok
# <div class="info"><h3 class="name">Adaptateur jack male vers 2 jack femelle</h3><div class="prc">14.00 TND</div><div class="s-prc-w"><div class="old">25.00 TND</div><div class="tag _dsct _sm">44%</div></div><p class="mpg" data-prc="14.00 TND" data-tot="2">offres à partir de</p><div class="rev"><div class="stars _s">3.9 out of 5<div class="in" style="width:78%"></div></div>(7)</div></div>
# Adaptateur jack male vers 2 jack femelle
# 44%
# 14.00 TND
# 25.00 TND
# ok
# <div class="info"><h3 class="name">VARTA 4 piles rechargeables AAA 800mAh 1.2v + CADEAU Porte clé-Its</h3><div class="prc">39.00 TND</div><div class="s-prc-w"><div class="old">58.00 TND</div><div class="tag _dsct _sm">33%</div></div><div class="rev"><div class="stars _s">4.7 out of 5<div class="in" style="width:94%"></div></div>(3)</div></div>
# VARTA 4 piles rechargeables AAA 800mAh 1.2v + CADEAU Porte clé-Its
# 33%
# 39.00 TND
# 58.00 TND
# ok
# <div class="info"><h3 class="name">Anycast M9 plus - Wifi HDMI - Clé de partage écran</h3><div class="prc">38.00 TND</div><div class="s-prc-w"><div class="old">65.00 TND</div><div class="tag _dsct _sm">42%</div></div></div>
# Anycast M9 plus - Wifi HDMI - Clé de partage écran
# 42%
# 38.00 TND
# 65.00 TND
# ok
# <div class="info"><h3 class="name">Samsung Téléviseur Smart 32" - FullHD - UA32T5300 - Garantie 2 ans</h3><div class="prc">868.80 TND</div><div class="s-prc-w"><div class="old">1,099.90 TND</div><div class="tag _dsct _sm">21%</div></div><p class="mpg" data-prc="868.80 TND" data-tot="2">offres à partir de</p><div class="rev"><div class="stars _s">5 out of 5<div class="in" style="width:100%"></div></div>(2)</div></div>
# Samsung Téléviseur Smart 32" - FullHD - UA32T5300 - Garantie 2 ans
# 21%
# 868.80 TND
# 1,099.90 TND
# ok
# <div class="info"><h3 class="name">Détecteur localisateur de signal -Satellite Numérique</h3><div class="prc">32.99 TND</div><p class="mpg" data-prc="32.99 TND" data-tot="3">offres à partir de</p><div class="rev"><div class="stars _s">3.3 out of 5<div class="in" style="width:66%"></div></div>(8)</div></div>
# Détecteur localisateur de signal -Satellite Numérique
# 32.99 TND
# ok
# <div class="info"><h3 class="name">Support Mural Pivotant - Pour TV  Max 14 "- 55"</h3><div class="prc">33.00 TND</div><div class="s-prc-w"><div class="old">65.00 TND</div><div class="tag _dsct _sm">49%</div></div><p class="mpg" data-prc="33.00 TND" data-tot="3">offres à partir de</p><div class="rev"><div class="stars _s">4 out of 5<div class="in" style="width:80%"></div></div>(13)</div></div>
# Support Mural Pivotant - Pour TV Max 14 "- 55"
# 49%
# 33.00 TND
# 65.00 TND
# ok
# <div class="info"><h3 class="name">Arduino W1209 - Mini - Thermostat - Contrôleur  De  Température</h3><div class="prc">19.00 TND</div><div class="s-prc-w"><div class="old">29.00 TND</div><div class="tag _dsct _sm">34%</div></div><div class="rev"><div class="stars _s">4.1 out of 5<div class="in" style="width:81.99999999999999%"></div></div>(39)</div></div>
# Arduino W1209 - Mini - Thermostat - Contrôleur De Température
# 34%
# 19.00 TND
# 29.00 TND
# ok
# <div class="info"><h3 class="name">Sjcam Gimbal2-Stabilisateur-3 axes-action cam</h3><div class="prc">200.00 TND</div><div class="s-prc-w"><div class="old">680.00 TND</div><div class="tag _dsct _sm">71%</div></div></div>
# Sjcam Gimbal2-Stabilisateur-3 axes-action cam
# 71%
# 200.00 TND
# 680.00 TND
# ok
# <div class="info"><h3 class="name"></h3><div class="prc"></div></div>
#
#
# bonjour
# ok
# <div class="info"><h3 class="name"></h3><div class="prc"></div></div>
#
#
# bonjour
# ok
# <div class="info"><h3 class="name"></h3><div class="prc"></div></div>
#
#
# bonjour
# ok
# <div class="info"><h3 class="name"></h3><div class="prc"></div></div>
#
#
# bonjour
# ok
# <div class="info"><h3 class="name"></h3><div class="prc"></div></div>
#
#
# bonjour
# ok
# <div class="info"><h3 class="name"></h3><div class="prc"></div></div>
#
#
# bonjour
# ok
# <div class="info"><h3 class="name"></h3><div class="prc"></div></div>
#
#
# bonjour
# ok
# <div class="info"><h3 class="name"></h3><div class="prc"></div></div>
#
#
# bonjour
# ok
# *****************************************
# *****************************************
# *****************************************
# *****************************************
# Numéro de la page à scrapper: 2
# Le nombre d'item est: 48
# ******************************************
# <div class="info"><h3 class="name">Smart watch - Rose</h3><div class="prc">32.00 TND</div><div class="s-prc-w"><div class="old">69.00 TND</div><div class="tag _dsct _sm">54%</div></div></div>
# Smart watch - Rose
# 54%
# 32.00 TND
# 69.00 TND
# ok
# <div class="info"><h3 class="name">tripod Trépied 3120A Support Camera &amp; Téléphone</h3><div class="prc">43.00 TND</div><div class="s-prc-w"><div class="old">119.00 TND</div><div class="tag _dsct _sm">64%</div></div><p class="mpg" data-prc="43.00 TND" data-tot="2">offres à partir de</p><div class="rev"><div class="stars _s">3.2 out of 5<div class="in" style="width:64%"></div></div>(10)</div></div>
# tripod Trépied 3120A Support Camera & Téléphone
# 64%
# 43.00 TND
# 119.00 TND
# ok
# <div class="info"><h3 class="name">XIAOMI Mi Home Security Camera 360° - 1080P - Blanc - Garantie 1 an</h3><div class="prc">79.00 TND</div><div class="s-prc-w"><div class="old">84.00 TND</div><div class="tag _dsct _sm">6%</div></div><svg aria-label="Livraison rapide" class="ic xprss" height="10" viewbox="0 0 114 12" width="94"><use xlink:href="https://www.jumia.com.tn/assets_he/images/i-shop-jumia.c8de1c55.svg#express"></use></svg><p class="shipp">Eligible à la livraison gratuite avec Jumia Express Ou Jumia Prime.</p></div>
# XIAOMI Mi Home Security Camera 360° - 1080P - Blanc - Garantie 1 an
# 6%
# 79.00 TND
# 84.00 TND
# ok
# <div class="info"><h3 class="name">SINGWAY Chargeur de Piles rechargeables AA/AAA NI-MH/NI-CD - 4 PCS</h3><div class="prc">25.00 TND</div><div class="s-prc-w"><div class="old">49.00 TND</div><div class="tag _dsct _sm">49%</div></div><div class="rev"><div class="stars _s">4.5 out of 5<div class="in" style="width:90%"></div></div>(2)</div></div>
# SINGWAY Chargeur de Piles rechargeables AA/AAA NI-MH/NI-CD - 4 PCS
# 49%
# 25.00 TND
# 49.00 TND
# ok
# <div class="info"><h3 class="name">XIAOMI Caméra de sécurité XIAOMI Home 360 ​​° 1080p</h3><div class="prc">149.00 TND</div><div class="s-prc-w"><div class="old">279.00 TND</div><div class="tag _dsct _sm">47%</div></div><div class="rev"><div class="stars _s">4 out of 5<div class="in" style="width:80%"></div></div>(22)</div></div>
# XIAOMI Caméra de sécurité XIAOMI Home 360 ​​° 1080p
# 47%
# 149.00 TND
# 279.00 TND
# ok
# <div class="info"><div class="tag _mall _sm">Boutique Officielle</div><h3 class="name">Toshiba Tv 43" Led  S2850 FHD - Noir</h3><div class="prc">939.00 TND</div><div class="s-prc-w"><div class="old">1,099.00 TND</div><div class="tag _dsct _sm">15%</div></div><svg aria-label="Livraison rapide" class="ic xprss" height="10" viewbox="0 0 114 12" width="94"><use xlink:href="https://www.jumia.com.tn/assets_he/images/i-shop-jumia.c8de1c55.svg#express"></use></svg><p class="shipp">Eligible à la livraison gratuite avec Jumia Express Ou Jumia Prime.</p></div>
# Toshiba Tv 43" Led S2850 FHD - Noir
# 15%
# 939.00 TND
# 1,099.00 TND
# ok
# <div class="info"><h3 class="name">Boya Micro cravate professionnel avec connecteur TRRS</h3><div class="prc">119.99 TND</div><div class="s-prc-w"><div class="old">150.00 TND</div><div class="tag _dsct _sm">20%</div></div><div class="rev"><div class="stars _s">2 out of 5<div class="in" style="width:40%"></div></div>(1)</div></div>
# Boya Micro cravate professionnel avec connecteur TRRS
# 20%
# 119.99 TND
# 150.00 TND
# ok
# <div class="info"><h3 class="name">XIAOMI Caméra de sécurité IP Wifi Home 360 ​​° 1080p</h3><div class="prc">119.00 TND</div><div class="s-prc-w"><div class="old">279.00 TND</div><div class="tag _dsct _sm">57%</div></div><div class="rev"><div class="stars _s">4.8 out of 5<div class="in" style="width:96%"></div></div>(12)</div></div>
# XIAOMI Caméra de sécurité IP Wifi Home 360 ​​° 1080p
# 57%
# 119.00 TND
# 279.00 TND
# ok
# <div class="info"><h3 class="name">Starsat Résolution-Satellite - FHD 1080p</h3><div class="prc">60.00 TND</div><div class="s-prc-w"><div class="old">79.00 TND</div><div class="tag _dsct _sm">24%</div></div></div>
# Starsat Résolution-Satellite - FHD 1080p
# 24%
# 60.00 TND
# 79.00 TND
# ok
# <div class="info"><h3 class="name">Telefunken Téléviseur - 32E20 - LED HD - Smart  - Garantie 3 ans</h3><div class="prc">754.90 TND</div><div class="s-prc-w"><div class="old">799.00 TND</div><div class="tag _dsct _sm">6%</div></div><div class="rev"><div class="stars _s">4.7 out of 5<div class="in" style="width:94%"></div></div>(11)</div></div>
# Telefunken Téléviseur - 32E20 - LED HD - Smart - Garantie 3 ans
# 6%
# 754.90 TND
# 799.00 TND
# ok
# <div class="info"><h3 class="name">Nsat Support Murale - 26"-55" - Noir</h3><div class="prc">12.00 TND</div><div class="s-prc-w"><div class="old">23.00 TND</div><div class="tag _dsct _sm">48%</div></div><div class="rev"><div class="stars _s">4.5 out of 5<div class="in" style="width:90%"></div></div>(4)</div></div>
# Nsat Support Murale - 26"-55" - Noir
# 48%
# 12.00 TND
# 23.00 TND
# ok
# <div class="info"><h3 class="name">Pack 5 lampe LED de lecture USB - Noir</h3><div class="prc">11.91 TND</div><div class="s-prc-w"><div class="old">40.00 TND</div><div class="tag _dsct _sm">70%</div></div><div class="rev"><div class="stars _s">3.3 out of 5<div class="in" style="width:66%"></div></div>(6)</div></div>
# Pack 5 lampe LED de lecture USB - Noir
# 70%
# 11.91 TND
# 40.00 TND
# ok
# <div class="info"><h3 class="name">Brosse à air chaud 3-en-1  - Lisseur, appareil à boucler</h3><div class="prc">99.00 TND</div><div class="s-prc-w"><div class="old">155.00 TND</div><div class="tag _dsct _sm">36%</div></div><div class="rev"><div class="stars _s">5 out of 5<div class="in" style="width:100%"></div></div>(1)</div></div>
# Brosse à air chaud 3-en-1 - Lisseur, appareil à boucler
# 36%
# 99.00 TND
# 155.00 TND
# ok
# <div class="info"><h3 class="name">Adaptateur Casque Jack vers 2xJack - PC vers GSM</h3><div class="prc">7.40 TND</div><div class="s-prc-w"><div class="old">16.00 TND</div><div class="tag _dsct _sm">54%</div></div><div class="rev"><div class="stars _s">4 out of 5<div class="in" style="width:80%"></div></div>(1)</div></div>
# Adaptateur Casque Jack vers 2xJack - PC vers GSM
# 54%
# 7.40 TND
# 16.00 TND
# ok
# <div class="info"><h3 class="name">Tag porte-clés de proximité -RFID Pack de 10 pièces</h3><div class="prc">26.00 TND</div><div class="rev"><div class="stars _s">4 out of 5<div class="in" style="width:80%"></div></div>(1)</div></div>
# Tag porte-clés de proximité -RFID Pack de 10 pièces
# 26.00 TND
# ok
# <div class="info"><h3 class="name">tripod Trépied avec hauteur réglable-Appareil photo- Smartphone</h3><div class="prc">45.00 TND</div><div class="s-prc-w"><div class="old">59.00 TND</div><div class="tag _dsct _sm">24%</div></div><div class="rev"><div class="stars _s">3.6 out of 5<div class="in" style="width:72%"></div></div>(5)</div></div>
# tripod Trépied avec hauteur réglable-Appareil photo- Smartphone
# 24%
# 45.00 TND
# 59.00 TND
# ok
# <div class="info"><h3 class="name">Papier photo Ultra White Lustré -250GR- A4</h3><div class="prc">17.00 TND</div><div class="rev"><div class="stars _s">4 out of 5<div class="in" style="width:80%"></div></div>(2)</div><svg aria-label="Livraison rapide" class="ic xprss" height="10" viewbox="0 0 114 12" width="94"><use xlink:href="https://www.jumia.com.tn/assets_he/images/i-shop-jumia.c8de1c55.svg#express"></use></svg><p class="shipp">Eligible à la livraison gratuite avec Jumia Express Ou Jumia Prime.</p></div>
# Papier photo Ultra White Lustré -250GR- A4
# 17.00 TND
# ok
# <div class="info"><h3 class="name">Caméra extérieur - étanche - wifi - 360° -</h3><div class="prc">229.00 TND</div><div class="s-prc-w"><div class="old">279.00 TND</div><div class="tag _dsct _sm">18%</div></div><div class="rev"><div class="stars _s">3.6 out of 5<div class="in" style="width:72%"></div></div>(5)</div></div>
# Caméra extérieur - étanche - wifi - 360° -
# 18%
# 229.00 TND
# 279.00 TND
# ok
# <div class="info"><h3 class="name">Fujifilm Instax mini film - packs de 2X10 films</h3><div class="prc">69.00 TND</div><div class="rev"><div class="stars _s">4 out of 5<div class="in" style="width:80%"></div></div>(1)</div></div>
# Fujifilm Instax mini film - packs de 2X10 films
# 69.00 TND
# ok
# <div class="info"><h3 class="name">VARTA 4 piles rechargeables AA 2100mAh 1.2v &amp; Porte Clé cadeau - Its</h3><div class="prc">49.00 TND</div><div class="s-prc-w"><div class="old">58.00 TND</div><div class="tag _dsct _sm">16%</div></div><div class="rev"><div class="stars _s">4.2 out of 5<div class="in" style="width:84%"></div></div>(17)</div></div>
# VARTA 4 piles rechargeables AA 2100mAh 1.2v & Porte Clé cadeau - Its
# 16%
# 49.00 TND
# 58.00 TND
# ok
# <div class="info"><h3 class="name">SOEWEL Radio Smart - Rechargeable - MP3 / USB /rouge</h3><div class="prc">37.00 TND</div><div class="s-prc-w"><div class="old">80.00 TND</div><div class="tag _dsct _sm">54%</div></div><div class="rev"><div class="stars _s">3.3 out of 5<div class="in" style="width:66%"></div></div>(4)</div></div>
# SOEWEL Radio Smart - Rechargeable - MP3 / USB /rouge
# 54%
# 37.00 TND
# 80.00 TND
# ok
# <div class="info"><h3 class="name">Lot de 5 piles au lithium CR2032 BR2032 2032 / 3 V</h3><div class="prc">8.00 TND</div><div class="s-prc-w"><div class="old">18.00 TND</div><div class="tag _dsct _sm">56%</div></div><p class="mpg" data-prc="8.00 TND" data-tot="2">offres à partir de</p><div class="rev"><div class="stars _s">3.9 out of 5<div class="in" style="width:78%"></div></div>(9)</div></div>
# Lot de 5 piles au lithium CR2032 BR2032 2032 / 3 V
# 56%
# 8.00 TND
# 18.00 TND
# ok
# <div class="info"><h3 class="name">Cable jack RCA 5M</h3><div class="prc">12.50 TND</div><div class="s-prc-w"><div class="old">15.00 TND</div><div class="tag _dsct _sm">17%</div></div><div class="rev"><div class="stars _s">5 out of 5<div class="in" style="width:100%"></div></div>(1)</div></div>
# Cable jack RCA 5M
# 17%
# 12.50 TND
# 15.00 TND
# ok
# <div class="info"><h3 class="name">Adaptateur Jack Bluetooth</h3><div class="prc">29.00 TND</div><div class="rev"><div class="stars _s">3.2 out of 5<div class="in" style="width:64%"></div></div>(20)</div></div>
# Adaptateur Jack Bluetooth
# 29.00 TND
# ok
# <div class="info"><h3 class="name">Cable HDMI - 5Metres - Noir</h3><div class="prc">15.50 TND</div><div class="rev"><div class="stars _s">4.5 out of 5<div class="in" style="width:90%"></div></div>(2)</div></div>
# Cable HDMI - 5Metres - Noir
# 15.50 TND
# ok
# <div class="info"><h3 class="name">Lecteur Adaptateur Carte SD Vers USB Et Micro USB - ASD-3</h3><div class="prc">6.50 TND</div><p class="mpg" data-prc="6.50 TND" data-tot="3">offres à partir de</p></div>
# Lecteur Adaptateur Carte SD Vers USB Et Micro USB - ASD-3
# 6.50 TND
# ok
# <div class="info"><h3 class="name">Arduino 4 x Batterie Lithium 3.7v 3800mAh</h3><div class="prc">57.95 TND</div><div class="s-prc-w"><div class="old">80.00 TND</div><div class="tag _dsct _sm">28%</div></div></div>
# Arduino 4 x Batterie Lithium 3.7v 3800mAh
# 28%
# 57.95 TND
# 80.00 TND
# ok
# <div class="info"><h3 class="name">Câble hdmi - 3m</h3><div class="prc">8.00 TND</div><div class="s-prc-w"><div class="old">10.00 TND</div><div class="tag _dsct _sm">20%</div></div><div class="rev"><div class="stars _s">4.3 out of 5<div class="in" style="width:86%"></div></div>(63)</div></div>
# Câble hdmi - 3m
# 20%
# 8.00 TND
# 10.00 TND
# ok
# <div class="info"><h3 class="name">Roadstar Radio réveil CLR-2477</h3><div class="prc">61.80 TND</div><div class="s-prc-w"><div class="old">78.00 TND</div><div class="tag _dsct _sm">21%</div></div><div class="rev"><div class="stars _s">3.6 out of 5<div class="in" style="width:72%"></div></div>(25)</div></div>
# Roadstar Radio réveil CLR-2477
# 21%
# 61.80 TND
# 78.00 TND
# ok
# <div class="info"><h3 class="name">Câble PS2/PS3 - 1.8 m</h3><div class="prc">13.00 TND</div><div class="s-prc-w"><div class="old">19.00 TND</div><div class="tag _dsct _sm">32%</div></div><p class="mpg" data-prc="13.00 TND" data-tot="2">offres à partir de</p></div>
# Câble PS2/PS3 - 1.8 m
# 32%
# 13.00 TND
# 19.00 TND
# ok
# <div class="info"><div class="tag _mall _sm">Boutique Officielle</div><h3 class="name">Vega Smart TV UHD - 50" - Android - F50F1UBG - Garantie 3 Ans</h3><div class="prc">1,519.00 TND</div><div class="s-prc-w"><div class="old">1,899.00 TND</div><div class="tag _dsct _sm">20%</div></div><p class="mpg" data-prc="1,519.00 TND" data-tot="2">offres à partir de</p><svg aria-label="Livraison rapide" class="ic xprss" height="10" viewbox="0 0 114 12" width="94"><use xlink:href="https://www.jumia.com.tn/assets_he/images/i-shop-jumia.c8de1c55.svg#express"></use></svg><p class="shipp">Eligible à la livraison gratuite avec Jumia Express Ou Jumia Prime.</p></div>
# Vega Smart TV UHD - 50" - Android - F50F1UBG - Garantie 3 Ans
# 20%
# 1,519.00 TND
# 1,899.00 TND
# ok
# <div class="info"><h3 class="name">Arduino Batterie Lithium 3.7v 3800mAh</h3><div class="prc">16.99 TND</div><div class="s-prc-w"><div class="old">25.00 TND</div><div class="tag _dsct _sm">32%</div></div><div class="rev"><div class="stars _s">4 out of 5<div class="in" style="width:80%"></div></div>(1)</div></div>
# Arduino Batterie Lithium 3.7v 3800mAh
# 32%
# 16.99 TND
# 25.00 TND
# ok
# <div class="info"><h3 class="name">Cosse pince batterie - 800AMP - Câbles de démarrage</h3><div class="prc">31.90 TND</div><div class="s-prc-w"><div class="old">60.00 TND</div><div class="tag _dsct _sm">47%</div></div><p class="mpg" data-prc="31.90 TND" data-tot="3">offres à partir de</p><div class="rev"><div class="stars _s">3.3 out of 5<div class="in" style="width:66%"></div></div>(6)</div></div>
# Cosse pince batterie - 800AMP - Câbles de démarrage
# 47%
# 31.90 TND
# 60.00 TND
# ok
# <div class="info"><h3 class="name">Meier Radio FM/AM/SW avec Bluetooth, Entrée jack, Carte SD &amp; Clé USB - Style Rétro Classique</h3><div class="prc">69.80 TND</div><div class="s-prc-w"><div class="old">99.00 TND</div><div class="tag _dsct _sm">29%</div></div></div>
# Meier Radio FM/AM/SW avec Bluetooth, Entrée jack, Carte SD & Clé USB - Style Rétro Classique
# 29%
# 69.80 TND
# 99.00 TND
# ok
# <div class="info"><h3 class="name">D-Link Mini caméra Wi Fi HD DCS 8000LH</h3><div class="prc">129.00 TND</div><div class="rev"><div class="stars _s">3.3 out of 5<div class="in" style="width:66%"></div></div>(3)</div></div>
# D-Link Mini caméra Wi Fi HD DCS 8000LH
# 129.00 TND
# ok
# <div class="info"><h3 class="name">Lionix Baffle bluetooth</h3><div class="prc">479.00 TND</div><div class="s-prc-w"><div class="old">550.00 TND</div><div class="tag _dsct _sm">13%</div></div><p class="mpg" data-prc="479.00 TND" data-tot="2">offres à partir de</p></div>
# Lionix Baffle bluetooth
# 13%
# 479.00 TND
# 550.00 TND
# ok
# <div class="info"><h3 class="name">Câble HDMI Connexion plaquée Or pour 1080P / 4K * 2K, 1,5 m</h3><div class="prc">7.50 TND</div><div class="s-prc-w"><div class="old">11.00 TND</div><div class="tag _dsct _sm">32%</div></div></div>
# Câble HDMI Connexion plaquée Or pour 1080P / 4K * 2K, 1,5 m
# 32%
# 7.50 TND
# 11.00 TND
# ok
# <div class="info"><h3 class="name">Support Mural TV 14"-42"  - Fixe - Noir</h3><div class="prc">11.90 TND</div><div class="s-prc-w"><div class="old">22.00 TND</div><div class="tag _dsct _sm">46%</div></div><p class="mpg" data-prc="11.90 TND" data-tot="5">offres à partir de</p><div class="rev"><div class="stars _s">5 out of 5<div class="in" style="width:100%"></div></div>(2)</div></div>
# Support Mural TV 14"-42" - Fixe - Noir
# 46%
# 11.90 TND
# 22.00 TND
# ok
# <div class="info"><h3 class="name">CAMBOFOTO Mini Tripod-CAMBOFOTO-M7</h3><div class="prc">50.00 TND</div><div class="s-prc-w"><div class="old">65.00 TND</div><div class="tag _dsct _sm">23%</div></div><div class="rev"><div class="stars _s">4 out of 5<div class="in" style="width:80%"></div></div>(1)</div></div>
# CAMBOFOTO Mini Tripod-CAMBOFOTO-M7
# 23%
# 50.00 TND
# 65.00 TND
# ok
# <div class="info"><h3 class="name">Anycast USB Dongle HDMI Wifi - Récepteur d'affichage</h3><div class="prc">29.60 TND</div><div class="s-prc-w"><div class="old">99.00 TND</div><div class="tag _dsct _sm">70%</div></div><p class="mpg" data-prc="29.60 TND" data-tot="2">offres à partir de</p><div class="rev"><div class="stars _s">3.4 out of 5<div class="in" style="width:68%"></div></div>(10)</div></div>
# Anycast USB Dongle HDMI Wifi - Récepteur d'affichage
# 70%
# 29.60 TND
# 99.00 TND
# ok
# <div class="info"><h3 class="name"></h3><div class="prc"></div></div>
#
#
# bonjour
# ok
# <div class="info"><h3 class="name"></h3><div class="prc"></div></div>
#
#
# bonjour
# ok
# <div class="info"><h3 class="name"></h3><div class="prc"></div></div>
#
#
# bonjour
# ok
# <div class="info"><h3 class="name"></h3><div class="prc"></div></div>
#
#
# bonjour
# ok
# <div class="info"><h3 class="name"></h3><div class="prc"></div></div>
#
#
# bonjour
# ok
# <div class="info"><h3 class="name"></h3><div class="prc"></div></div>
#
#
# bonjour
# ok
# <div class="info"><h3 class="name"></h3><div class="prc"></div></div>
#
#
# bonjour
# ok
# <div class="info"><h3 class="name"></h3><div class="prc"></div></div>
#
#
# bonjour
# ok
# *****************************************
# *****************************************
# *****************************************
# *****************************************
# Numéro de la page à scrapper: 3
# Le nombre d'item est: 48
# ******************************************
# <div class="info"><h3 class="name">Hdmi And More Adaptateur switch - commutateur - distributeur - 5 à 1</h3><div class="prc">53.00 TND</div><div class="rev"><div class="stars _s">3.7 out of 5<div class="in" style="width:74%"></div></div>(3)</div></div>
# Hdmi And More Adaptateur switch - commutateur - distributeur - 5 à 1
# 53.00 TND
# ok
# <div class="info"><h3 class="name">Câble HDMI plat v2.0/1.4 4k x 2k 10m - Noir</h3><div class="prc">22.00 TND</div><div class="s-prc-w"><div class="old">27.00 TND</div><div class="tag _dsct _sm">19%</div></div><div class="rev"><div class="stars _s">4.5 out of 5<div class="in" style="width:90%"></div></div>(2)</div></div>
# Câble HDMI plat v2.0/1.4 4k x 2k 10m - Noir
# 19%
# 22.00 TND
# 27.00 TND
# ok
# <div class="info"><h3 class="name">Onvif Caméra de surveillance - 3 Antennes - HD Infrarouge - IP wifi</h3><div class="prc">129.00 TND</div><div class="s-prc-w"><div class="old">199.00 TND</div><div class="tag _dsct _sm">35%</div></div><p class="mpg" data-prc="129.00 TND" data-tot="3">offres à partir de</p><div class="rev"><div class="stars _s">4.4 out of 5<div class="in" style="width:88.00000000000001%"></div></div>(19)</div></div>
# Onvif Caméra de surveillance - 3 Antennes - HD Infrarouge - IP wifi
# 35%
# 129.00 TND
# 199.00 TND
# ok
# <div class="info"><h3 class="name">Cable hdmi - Ultra HD 4k 3mt</h3><div class="prc">13.00 TND</div><div class="s-prc-w"><div class="old">25.00 TND</div><div class="tag _dsct _sm">48%</div></div><p class="mpg" data-prc="13.00 TND" data-tot="2">offres à partir de</p><div class="rev"><div class="stars _s">4.4 out of 5<div class="in" style="width:88.00000000000001%"></div></div>(8)</div></div>
# Cable hdmi - Ultra HD 4k 3mt
# 48%
# 13.00 TND
# 25.00 TND
# ok
# <div class="info"><h3 class="name">WAXIBA Radio Smart - Rechargeable - MP3 / USB / - Marron</h3><div class="prc">45.00 TND</div><div class="s-prc-w"><div class="old">70.00 TND</div><div class="tag _dsct _sm">36%</div></div><p class="mpg" data-prc="45.00 TND" data-tot="2">offres à partir de</p><div class="rev"><div class="stars _s">4 out of 5<div class="in" style="width:80%"></div></div>(25)</div></div>
# WAXIBA Radio Smart - Rechargeable - MP3 / USB / - Marron
# 36%
# 45.00 TND
# 70.00 TND
# ok
# <div class="info"><h3 class="name">STAR ONE Plaque De Cuisson À Gaz 5 Feux Inox - Garantie 1 an</h3><div class="prc">229.90 TND</div><div class="s-prc-w"><div class="old">269.00 TND</div><div class="tag _dsct _sm">15%</div></div><p class="mpg" data-prc="229.90 TND" data-tot="2">offres à partir de</p><div class="rev"><div class="stars _s">4.8 out of 5<div class="in" style="width:96%"></div></div>(5)</div><svg aria-label="Livraison rapide" class="ic xprss" height="10" viewbox="0 0 114 12" width="94"><use xlink:href="https://www.jumia.com.tn/assets_he/images/i-shop-jumia.c8de1c55.svg#express"></use></svg><p class="shipp">Eligible à la livraison gratuite avec Jumia Express Ou Jumia Prime.</p></div>
# STAR ONE Plaque De Cuisson À Gaz 5 Feux Inox - Garantie 1 an
# 15%
# 229.90 TND
# 269.00 TND
# ok
# <div class="info"><h3 class="name">Convert Digital to Analog Audio Converter</h3><div class="prc">73.00 TND</div></div>
# Convert Digital to Analog Audio Converter
# 73.00 TND
# ok
# <div class="info"><h3 class="name">HDMI Repeater 4K*2k &amp;adaptateur HDMI femelle&amp;femelle</h3><div class="prc">9.99 TND</div><div class="s-prc-w"><div class="old">24.90 TND</div><div class="tag _dsct _sm">60%</div></div><div class="rev"><div class="stars _s">3 out of 5<div class="in" style="width:60%"></div></div>(2)</div></div>
# HDMI Repeater 4K*2k &adaptateur HDMI femelle&femelle
# 60%
# 9.99 TND
# 24.90 TND
# ok
# <div class="info"><h3 class="name">Clé wifi - USB avec antenne</h3><div class="prc">10.40 TND</div><div class="s-prc-w"><div class="old">25.00 TND</div><div class="tag _dsct _sm">58%</div></div><p class="mpg" data-prc="10.40 TND" data-tot="5">offres à partir de</p><div class="rev"><div class="stars _s">3.6 out of 5<div class="in" style="width:72%"></div></div>(36)</div></div>
# Clé wifi - USB avec antenne
# 58%
# 10.40 TND
# 25.00 TND
# ok
# <div class="info"><h3 class="name">Graveur dvd externe usb 3.0</h3><div class="prc">75.90 TND</div><div class="s-prc-w"><div class="old">85.00 TND</div><div class="tag _dsct _sm">11%</div></div><p class="mpg" data-prc="75.90 TND" data-tot="5">offres à partir de</p><div class="rev"><div class="stars _s">3.5 out of 5<div class="in" style="width:70%"></div></div>(2)</div></div>
# Graveur dvd externe usb 3.0
# 11%
# 75.90 TND
# 85.00 TND
# ok
# <div class="info"><h3 class="name">Nikon Dslr Saccoche pour DSLR-NIKON</h3><div class="prc">80.00 TND</div><div class="s-prc-w"><div class="old">95.00 TND</div><div class="tag _dsct _sm">16%</div></div></div>
# Nikon Dslr Saccoche pour DSLR-NIKON
# 16%
# 80.00 TND
# 95.00 TND
# ok
# <div class="info"><h3 class="name">Sony Lecteur DVD - Sony - Noir - Usb - Garantie 1 an</h3><div class="prc">169.00 TND</div><div class="s-prc-w"><div class="old">199.00 TND</div><div class="tag _dsct _sm">15%</div></div><div class="rev"><div class="stars _s">5 out of 5<div class="in" style="width:100%"></div></div>(8)</div></div>
# Sony Lecteur DVD - Sony - Noir - Usb - Garantie 1 an
# 15%
# 169.00 TND
# 199.00 TND
# ok
# <div class="info"><h3 class="name">Fojax Speaker Bluetooth Portable - Haut-Parleur Sans Fil Batterie</h3><div class="prc">34.00 TND</div><div class="s-prc-w"><div class="old">49.00 TND</div><div class="tag _dsct _sm">31%</div></div></div>
# Fojax Speaker Bluetooth Portable - Haut-Parleur Sans Fil Batterie
# 31%
# 34.00 TND
# 49.00 TND
# ok
# <div class="info"><h3 class="name">Vega Barre de Son - Bluetooth - 40W - Gris - Garantie 1an</h3><div class="prc">176.00 TND</div><div class="s-prc-w"><div class="old">279.00 TND</div><div class="tag _dsct _sm">37%</div></div><div class="rev"><div class="stars _s">4.5 out of 5<div class="in" style="width:90%"></div></div>(2)</div></div>
# Vega Barre de Son - Bluetooth - 40W - Gris - Garantie 1an
# 37%
# 176.00 TND
# 279.00 TND
# ok
# <div class="info"><h3 class="name">Télécommande air fly mouse &amp; clavier sans fil</h3><div class="prc">38.70 TND</div><div class="s-prc-w"><div class="old">60.00 TND</div><div class="tag _dsct _sm">36%</div></div><div class="rev"><div class="stars _s">4.3 out of 5<div class="in" style="width:86%"></div></div>(7)</div></div>
# Télécommande air fly mouse & clavier sans fil
# 36%
# 38.70 TND
# 60.00 TND
# ok
# <div class="info"><h3 class="name">Carte son - USB externe 7.1</h3><div class="prc">9.00 TND</div><div class="s-prc-w"><div class="old">15.00 TND</div><div class="tag _dsct _sm">40%</div></div><p class="mpg" data-prc="9.00 TND" data-tot="5">offres à partir de</p><div class="rev"><div class="stars _s">3.7 out of 5<div class="in" style="width:74%"></div></div>(62)</div><svg aria-label="Livraison rapide" class="ic xprss" height="10" viewbox="0 0 114 12" width="94"><use xlink:href="https://www.jumia.com.tn/assets_he/images/i-shop-jumia.c8de1c55.svg#express"></use></svg><p class="shipp">Eligible à la livraison gratuite avec Jumia Express Ou Jumia Prime.</p></div>
# Carte son - USB externe 7.1
# 40%
# 9.00 TND
# 15.00 TND
# ok
# <div class="info"><h3 class="name">Sony NH-AAA-B2EN - 2 Piles rechargeables - AAA - 900 MA</h3><div class="prc">14.00 TND</div><div class="s-prc-w"><div class="old">22.00 TND</div><div class="tag _dsct _sm">36%</div></div><div class="rev"><div class="stars _s">4.1 out of 5<div class="in" style="width:81.99999999999999%"></div></div>(68)</div></div>
# Sony NH-AAA-B2EN - 2 Piles rechargeables - AAA - 900 MA
# 36%
# 14.00 TND
# 22.00 TND
# ok
# <div class="info"><h3 class="name">xb Poste Radio - Mp3 Player - bluetooth- Usb / Jack</h3><div class="prc">65.00 TND</div><div class="s-prc-w"><div class="old">120.00 TND</div><div class="tag _dsct _sm">46%</div></div></div>
# xb Poste Radio - Mp3 Player - bluetooth- Usb / Jack
# 46%
# 65.00 TND
# 120.00 TND
# ok
# <div class="info"><h3 class="name">Nsat Switch 4 En1 DISEqC  - Etanche</h3><div class="prc">10.00 TND</div><div class="s-prc-w"><div class="old">17.00 TND</div><div class="tag _dsct _sm">41%</div></div><div class="rev"><div class="stars _s">3 out of 5<div class="in" style="width:60%"></div></div>(2)</div></div>
# Nsat Switch 4 En1 DISEqC - Etanche
# 41%
# 10.00 TND
# 17.00 TND
# ok
# <div class="info"><h3 class="name">Nsat Support mural mobile  pour tv 32" - 47" - noir</h3><div class="prc">59.00 TND</div><div class="s-prc-w"><div class="old">85.00 TND</div><div class="tag _dsct _sm">31%</div></div></div>
# Nsat Support mural mobile pour tv 32" - 47" - noir
# 31%
# 59.00 TND
# 85.00 TND
# ok
# <div class="info"><h3 class="name">Atico Microscope pour étudiants - Noir &amp; blanc</h3><div class="prc">165.00 TND</div><div class="s-prc-w"><div class="old">195.00 TND</div><div class="tag _dsct _sm">15%</div></div><div class="rev"><div class="stars _s">2 out of 5<div class="in" style="width:40%"></div></div>(1)</div></div>
# Atico Microscope pour étudiants - Noir & blanc
# 15%
# 165.00 TND
# 195.00 TND
# ok
# <div class="info"><h3 class="name">Samsung Téléviseur LED 43" 4K - UA43TU7000 - Garantie 2 ans</h3><div class="prc">1,505.00 TND</div><div class="s-prc-w"><div class="old">2,189.00 TND</div><div class="tag _dsct _sm">31%</div></div><p class="mpg" data-prc="1,505.00 TND" data-tot="2">offres à partir de</p><div class="rev"><div class="stars _s">5 out of 5<div class="in" style="width:100%"></div></div>(3)</div></div>
# Samsung Téléviseur LED 43" 4K - UA43TU7000 - Garantie 2 ans
# 31%
# 1,505.00 TND
# 2,189.00 TND
# ok
# ...
# Hilook By Hikvision Pack 8 Caméras surveillance 2MP + XVR 8 - color vu - full color
# 28%
# 1,645.00 TND
# 2,300.00 TND
# ok
# <div class="info"><h3 class="name">Hilook By Hikvision Pack 8 Caméras surveillance HD 4MP + DVR de 8 - UP TO 8MP</h3><div class="prc">1,667.00 TND</div><div class="s-prc-w"><div class="old">1,850.00 TND</div><div class="tag _dsct _sm">10%</div></div></div>
# Hilook By Hikvision Pack 8 Caméras surveillance HD 4MP + DVR de 8 - UP TO 8MP
# 10%
# 1,667.00 TND
# 1,850.00 TND
# ok
# <div class="info"><h3 class="name">Hilook By Hikvision Pack 6 Caméras surveillance (3tube-40M/3dôme) 2MP - color vu - full color</h3><div class="prc">1,345.00 TND</div><div class="s-prc-w"><div class="old">1,885.00 TND</div><div class="tag _dsct _sm">29%</div></div></div>
# Hilook By Hikvision Pack 6 Caméras surveillance (3tube-40M/3dôme) 2MP - color vu - full color
# 29%
# 1,345.00 TND
# 1,885.00 TND
# ok
# <div class="info"><h3 class="name">Cable 3 RCA vers 3 RCA - 1.5 mètres - Noir</h3><div class="prc">8.00 TND</div><div class="rev"><div class="stars _s">5 out of 5<div class="in" style="width:100%"></div></div>(2)</div></div>
# Cable 3 RCA vers 3 RCA - 1.5 mètres - Noir
# 8.00 TND
# ok
# <div class="info"><h3 class="name">Kingleen ecouteur iphone i31</h3><div class="prc">30.00 TND</div><div class="s-prc-w"><div class="old">55.00 TND</div><div class="tag _dsct _sm">45%</div></div></div>
# Kingleen ecouteur iphone i31
# 45%
# 30.00 TND
# 55.00 TND
# ok
# <div class="info"><h3 class="name">Nsat Câble HDMI 1,5 m - Câble vidéo - 1080p 4K - Noir</h3><div class="prc">12.50 TND</div><div class="s-prc-w"><div class="old">15.00 TND</div><div class="tag _dsct _sm">17%</div></div><div class="rev"><div class="stars _s">5 out of 5<div class="in" style="width:100%"></div></div>(1)</div></div>
# Nsat Câble HDMI 1,5 m - Câble vidéo - 1080p 4K - Noir
# 17%
# 12.50 TND
# 15.00 TND
# ok
# *****************************************
# *****************************************
# *****************************************
# *****************************************
# Numéro de la page à scrapper: 50
# Le nombre d'item est: 40
# ******************************************
# <div class="info"><h3 class="name">Support TV mural fixe 26-63 - max  50 kg</h3><div class="prc">35.00 TND</div><div class="s-prc-w"><div class="old">39.00 TND</div><div class="tag _dsct _sm">10%</div></div></div>
# Support TV mural fixe 26-63 - max 50 kg
# 10%
# 35.00 TND
# 39.00 TND
# ok
# <div class="info"><h3 class="name">Hikvision Enregistreur pour Caméras surveillance - DVR 16 Ports - UP TO 4MP -</h3><div class="prc">698.00 TND</div><div class="s-prc-w"><div class="old">869.00 TND</div><div class="tag _dsct _sm">20%</div></div></div>
# Hikvision Enregistreur pour Caméras surveillance - DVR 16 Ports - UP TO 4MP -
# 20%
# 698.00 TND
# 869.00 TND
# ok
# <div class="info"><h3 class="name">Arduino Support batterie 3 x 18650</h3><div class="prc">20.00 TND</div><div class="rev"><div class="stars _s">4 out of 5<div class="in" style="width:80%"></div></div>(1)</div></div>
# Arduino Support batterie 3 x 18650
# 20.00 TND
# ok
# <div class="info"><h3 class="name">Hilook By Hikvision Pack 4 Caméras surveillance 2MP IP POE + NVR de 4 UP TO 8MP - Kit Complet</h3><div class="prc">885.00 TND</div><div class="s-prc-w"><div class="old">1,065.00 TND</div><div class="tag _dsct _sm">17%</div></div></div>
# Hilook By Hikvision Pack 4 Caméras surveillance 2MP IP POE + NVR de 4 UP TO 8MP - Kit Complet
# 17%
# 885.00 TND
# 1,065.00 TND
# ok
# <div class="info"><h3 class="name">Sony Adaptateur secteur - AC-L100 - Sony</h3><div class="prc">109.00 TND</div></div>
# Sony Adaptateur secteur - AC-L100 - Sony
# 109.00 TND
# ok
# <div class="info"><h3 class="name">Rca 3 RCA vers 3 RCA - Câble vidéo - 1.5 mètres - Noir</h3><div class="prc">9.90 TND</div><div class="s-prc-w"><div class="old">20.00 TND</div><div class="tag _dsct _sm">51%</div></div></div>
# Rca 3 RCA vers 3 RCA - Câble vidéo - 1.5 mètres - Noir
# 51%
# 9.90 TND
# 20.00 TND
# ok
# <div class="info"><h3 class="name">Câble hdmi - Plat - 15m- Male - Male</h3><div class="prc">27.00 TND</div><div class="s-prc-w"><div class="old">38.00 TND</div><div class="tag _dsct _sm">29%</div></div><p class="mpg" data-prc="27.00 TND" data-tot="2">offres à partir de</p><div class="rev"><div class="stars _s">3 out of 5<div class="in" style="width:60%"></div></div>(2)</div></div>
# Câble hdmi - Plat - 15m- Male - Male
# 29%
# 27.00 TND
# 38.00 TND
# ok
# <div class="info"><h3 class="name">Hilook By Hikvision Pack 6 Caméras surveillance 4MP IP POE + NVR de 8 UNV - Kit Complet</h3><div class="prc">1,322.00 TND</div><div class="s-prc-w"><div class="old">1,850.00 TND</div><div class="tag _dsct _sm">29%</div></div></div>
# Hilook By Hikvision Pack 6 Caméras surveillance 4MP IP POE + NVR de 8 UNV - Kit Complet
# 29%
# 1,322.00 TND
# 1,850.00 TND
# ok
# <div class="info"><h3 class="name">Support Murale - fixe pour TV 14" - 42" - Noir</h3><div class="prc">13.50 TND</div></div>
# Support Murale - fixe pour TV 14" - 42" - Noir
# 13.50 TND
# ok
# <div class="info"><h3 class="name">Hikvision Pack 8 Caméras surveillance 2MP</h3><div class="prc">833.00 TND</div><div class="s-prc-w"><div class="old">1,656.00 TND</div><div class="tag _dsct _sm">50%</div></div></div>
# Hikvision Pack 8 Caméras surveillance 2MP
# 50%
# 833.00 TND
# 1,656.00 TND
# ok
# <div class="info"><h3 class="name">Hilook By Hikvision Pack 6 Caméras surveillance IP POE 2MP + NVR de 8 UP TO 8MP - Kit Complet -</h3><div class="prc">1,110.00 TND</div><div class="s-prc-w"><div class="old">1,470.00 TND</div><div class="tag _dsct _sm">24%</div></div></div>
# Hilook By Hikvision Pack 6 Caméras surveillance IP POE 2MP + NVR de 8 UP TO 8MP - Kit Complet -
# 24%
# 1,110.00 TND
# 1,470.00 TND
# ok
# <div class="info"><h3 class="name">Vega Casque Mirco V009 - Blanc</h3><div class="prc">9.00 TND</div><div class="s-prc-w"><div class="old">25.00 TND</div><div class="tag _dsct _sm">64%</div></div></div>
# Vega Casque Mirco V009 - Blanc
# 64%
# 9.00 TND
# 25.00 TND
# ok
# <div class="info"><h3 class="name">Arduino _ Leonardo _ R3</h3><div class="prc">59.00 TND</div><div class="s-prc-w"><div class="old">79.00 TND</div><div class="tag _dsct _sm">25%</div></div></div>
# Arduino _ Leonardo _ R3
# 25%
# 59.00 TND
# 79.00 TND
# ok
# <div class="info"><h3 class="name">UNV Kit 4 Caméras surveillance Dome  IP 2MP + 1 NVR 4 POE</h3><div class="prc">840.00 TND</div><div class="s-prc-w"><div class="old">1,010.00 TND</div><div class="tag _dsct _sm">17%</div></div></div>
# UNV Kit 4 Caméras surveillance Dome IP 2MP + 1 NVR 4 POE
# 17%
# 840.00 TND
# 1,010.00 TND
# ok
# <div class="info"><h3 class="name">Chaîne d'ampoule de 5 mètre et 10 ampoules pour décoration</h3><div class="prc">55.00 TND</div><div class="s-prc-w"><div class="old">75.00 TND</div><div class="tag _dsct _sm">27%</div></div></div>
# Chaîne d'ampoule de 5 mètre et 10 ampoules pour décoration
# 27%
# 55.00 TND
# 75.00 TND
# ok
# <div class="info"><h3 class="name">Hilook By Hikvision Pack 8 Caméras surveillance IP POE 2MP + NVR de 8 UP TO 8MP - Kit Complet -</h3><div class="prc">1,312.00 TND</div><div class="s-prc-w"><div class="old">1,575.00 TND</div><div class="tag _dsct _sm">17%</div></div></div>
# Hilook By Hikvision Pack 8 Caméras surveillance IP POE 2MP + NVR de 8 UP TO 8MP - Kit Complet -
# 17%
# 1,312.00 TND
# 1,575.00 TND
# ok
# <div class="info"><h3 class="name">Hilook By Hikvision Pack 6 Caméras surveillance 2MP IP POE + NVR de 8 UNV - Kit Complet</h3><div class="prc">1,165.00 TND</div><div class="s-prc-w"><div class="old">1,390.00 TND</div><div class="tag _dsct _sm">16%</div></div></div>
# Hilook By Hikvision Pack 6 Caméras surveillance 2MP IP POE + NVR de 8 UNV - Kit Complet
# 16%
# 1,165.00 TND
# 1,390.00 TND
# ok
# <div class="info"><h3 class="name">AD Microphone de surveillance ref  AU10</h3><div class="prc">33.00 TND</div><p class="mpg" data-prc="33.00 TND" data-tot="3">offres à partir de</p></div>
# AD Microphone de surveillance ref AU10
# 33.00 TND
# ok
# <div class="info"><h3 class="name">Lot De 10 Supports Mural TV 14"-42" Fixe + 1 Gratuit</h3><div class="prc">99.00 TND</div><div class="s-prc-w"><div class="old">179.00 TND</div><div class="tag _dsct _sm">45%</div></div></div>
# Lot De 10 Supports Mural TV 14"-42" Fixe + 1 Gratuit
# 45%
# 99.00 TND
# 179.00 TND
# ok
# <div class="info"><h3 class="name">Sbox Support TV mural fixe - PLB-7036F - Noir</h3><div class="prc">85.00 TND</div><div class="s-prc-w"><div class="old">95.00 TND</div><div class="tag _dsct _sm">11%</div></div><p class="mpg" data-prc="85.00 TND" data-tot="2">offres à partir de</p><div class="rev"><div class="stars _s">4 out of 5<div class="in" style="width:80%"></div></div>(1)</div></div>
# Sbox Support TV mural fixe - PLB-7036F - Noir
# 11%
# 85.00 TND
# 95.00 TND
# ok
# <div class="info"><h3 class="name">Cnc Ramps 1.4 2004 LCD Control</h3><div class="prc">49.00 TND</div><div class="s-prc-w"><div class="old">70.00 TND</div><div class="tag _dsct _sm">30%</div></div></div>
# Cnc Ramps 1.4 2004 LCD Control
# 30%
# 49.00 TND
# 70.00 TND
# ok
# <div class="info"><h3 class="name">Hilook By Hikvision Pack 4 Caméras surveillance 4MP IP POE + NVR de 4 UP TO 8MP - Kit Complet</h3><div class="prc">1,125.00 TND</div><div class="s-prc-w"><div class="old">1,345.00 TND</div><div class="tag _dsct _sm">16%</div></div></div>
# Hilook By Hikvision Pack 4 Caméras surveillance 4MP IP POE + NVR de 4 UP TO 8MP - Kit Complet
# 16%
# 1,125.00 TND
# 1,345.00 TND
# ok
# <div class="info"><h3 class="name">Hilook By Hikvision Pack 6 Caméras surveillance 2MP IP POE + NVR de 8 UP TO 8MP - Kit Complet</h3><div class="prc">1,110.00 TND</div><div class="s-prc-w"><div class="old">1,345.00 TND</div><div class="tag _dsct _sm">17%</div></div></div>
# Hilook By Hikvision Pack 6 Caméras surveillance 2MP IP POE + NVR de 8 UP TO 8MP - Kit Complet
# 17%
# 1,110.00 TND
# 1,345.00 TND
# ok
# <div class="info"><h3 class="name">Hilook By Hikvision Pack 2 Caméras surveillance 4MP IP POE + NVR de 4 UP TO 8MP - Kit Complet</h3><div class="prc">825.00 TND</div><div class="s-prc-w"><div class="old">990.00 TND</div><div class="tag _dsct _sm">17%</div></div></div>
# Hilook By Hikvision Pack 2 Caméras surveillance 4MP IP POE + NVR de 4 UP TO 8MP - Kit Complet
# 17%
# 825.00 TND
# 990.00 TND
# ok
# <div class="info"><h3 class="name">Hilook By Hikvision Pack 6 Caméras surveillance 4MP IP POE + NVR de 8 - UP TO 8MP - Kit Complet</h3><div class="prc">1,500.00 TND</div><div class="s-prc-w"><div class="old">1,800.00 TND</div><div class="tag _dsct _sm">17%</div></div></div>
# Hilook By Hikvision Pack 6 Caméras surveillance 4MP IP POE + NVR de 8 - UP TO 8MP - Kit Complet
# 17%
# 1,500.00 TND
# 1,800.00 TND
# ok
# <div class="info"><h3 class="name">UNV Kit 8 Caméras de surveillance IP 2MP + 1 NVR 8 POE</h3><div class="prc">1,450.00 TND</div><div class="s-prc-w"><div class="old">1,740.00 TND</div><div class="tag _dsct _sm">17%</div></div></div>
# UNV Kit 8 Caméras de surveillance IP 2MP + 1 NVR 8 POE
# 17%
# 1,450.00 TND
# 1,740.00 TND
# ok
# <div class="info"><h3 class="name">Adaptateur - peritel mâle/femelle - 3xrca pour ancien TV</h3><div class="prc">9.50 TND</div><div class="rev"><div class="stars _s">5 out of 5<div class="in" style="width:100%"></div></div>(1)</div></div>
# Adaptateur - peritel mâle/femelle - 3xrca pour ancien TV
# 9.50 TND
# ok
# <div class="info"><h3 class="name">Dahua Pack 8 Caméras surveillance 2MP + XVR 8 - color vu - full color</h3><div class="prc">1,605.00 TND</div><div class="s-prc-w"><div class="old">1,930.00 TND</div><div class="tag _dsct _sm">17%</div></div></div>
# Dahua Pack 8 Caméras surveillance 2MP + XVR 8 - color vu - full color
# 17%
# 1,605.00 TND
# 1,930.00 TND
# ok
# <div class="info"><h3 class="name">Speaker - Portable - Rechargeable - Bluetooth</h3><div class="prc">33.00 TND</div><div class="s-prc-w"><div class="old">69.00 TND</div><div class="tag _dsct _sm">52%</div></div></div>
# Speaker - Portable - Rechargeable - Bluetooth
# 52%
# 33.00 TND
# 69.00 TND
# ok
# <div class="info"><h3 class="name">Connectplus Câble HDMI 3m - Noir</h3><div class="prc">18.00 TND</div><div class="s-prc-w"><div class="old">25.00 TND</div><div class="tag _dsct _sm">28%</div></div></div>
# Connectplus Câble HDMI 3m - Noir
# 28%
# 18.00 TND
# 25.00 TND
# ok
# <div class="info"><h3 class="name">Arduino Module - Relais - 8 canaux 5V</h3><div class="prc">35.55 TND</div><div class="s-prc-w"><div class="old">36.00 TND</div><div class="tag _dsct _sm">1%</div></div></div>
# Arduino Module - Relais - 8 canaux 5V
# 1%
# 35.55 TND
# 36.00 TND
# ok
# <div class="info"><h3 class="name">Nsat Câble HDMI HDTV 5 m - Câble vidéo - 1080p 4K 2K - Noir</h3><div class="prc">19.00 TND</div><div class="s-prc-w"><div class="old">25.00 TND</div><div class="tag _dsct _sm">24%</div></div></div>
# Nsat Câble HDMI HDTV 5 m - Câble vidéo - 1080p 4K 2K - Noir
# 24%
# 19.00 TND
# 25.00 TND
# ok
# <div class="info"><h3 class="name">Hilook By Hikvision Pack 4 Caméras surveillance 2MP IP POE + NVR de 4 UP TO 4MP - Kit Complet</h3><div class="prc">685.00 TND</div><div class="s-prc-w"><div class="old">820.00 TND</div><div class="tag _dsct _sm">16%</div></div></div>
# Hilook By Hikvision Pack 4 Caméras surveillance 2MP IP POE + NVR de 4 UP TO 4MP - Kit Complet
# 16%
# 685.00 TND
# 820.00 TND
# ok
# <div class="info"><h3 class="name">Kodak 4 Piles - Super Heavy Duty Zinc - 1.5V - Cx2</h3><div class="prc">21.00 TND</div><div class="s-prc-w"><div class="old">29.00 TND</div><div class="tag _dsct _sm">28%</div></div></div>
# Kodak 4 Piles - Super Heavy Duty Zinc - 1.5V - Cx2
# 28%
# 21.00 TND
# 29.00 TND
# ok
# <div class="info"><h3 class="name">Câble Lightning vers USB pour iPhone, iPad, AirPods - 1m</h3><div class="prc">8.99 TND</div><div class="s-prc-w"><div class="old">45.00 TND</div><div class="tag _dsct _sm">80%</div></div><p class="mpg" data-prc="8.99 TND" data-tot="4">offres à partir de</p><div class="rev"><div class="stars _s">3.3 out of 5<div class="in" style="width:66%"></div></div>(60)</div></div>
# Câble Lightning vers USB pour iPhone, iPad, AirPods - 1m
# 80%
# 8.99 TND
# 45.00 TND
# ok
# <div class="info"><h3 class="name">Cable hdmi - Ultra HD 4k 10 mt</h3><div class="prc">36.00 TND</div><div class="s-prc-w"><div class="old">45.00 TND</div><div class="tag _dsct _sm">20%</div></div><p class="mpg" data-prc="36.00 TND" data-tot="2">offres à partir de</p></div>
# Cable hdmi - Ultra HD 4k 10 mt
# 20%
# 36.00 TND
# 45.00 TND
# ok
# <div class="info"><h3 class="name">cable hdmi plat 15 mt</h3><div class="prc">26.00 TND</div><div class="s-prc-w"><div class="old">42.00 TND</div><div class="tag _dsct _sm">38%</div></div><div class="rev"><div class="stars _s">4 out of 5<div class="in" style="width:80%"></div></div>(1)</div></div>
# cable hdmi plat 15 mt
# 38%
# 26.00 TND
# 42.00 TND
# ok
# <div class="info"><h3 class="name">Nsat Câble HDMI HDTV 1.5 m - Câble vidéo - 1080p 4K 2K - Noir</h3><div class="prc">7.00 TND</div><div class="s-prc-w"><div class="old">10.00 TND</div><div class="tag _dsct _sm">30%</div></div><p class="mpg" data-prc="7.00 TND" data-tot="2">offres à partir de</p></div>
# Nsat Câble HDMI HDTV 1.5 m - Câble vidéo - 1080p 4K 2K - Noir
# 30%
# 7.00 TND
# 10.00 TND
# ok
# <div class="info"><h3 class="name">Hilook By Hikvision Pack 4 Caméras surveillance IP POE 2MP + NVR de 4 UP TO 8MP - Kit Complet -</h3><div class="prc">895.00 TND</div><div class="s-prc-w"><div class="old">1,075.00 TND</div><div class="tag _dsct _sm">17%</div></div></div>
# Hilook By Hikvision Pack 4 Caméras surveillance IP POE 2MP + NVR de 4 UP TO 8MP - Kit Complet -
# 17%
# 895.00 TND
# 1,075.00 TND
# ok
# <div class="info"><h3 class="name">Hilook By Hikvision Pack 6 Caméras surveillance (2tube-40M/4dôme) 2MP - color vu - full color</h3><div class="prc">1,330.00 TND</div><div class="s-prc-w"><div class="old">1,598.00 TND</div><div class="tag _dsct _sm">17%</div></div></div>
# Hilook By Hikvision Pack 6 Caméras surveillance (2tube-40M/4dôme) 2MP - color vu - full color
# 17%
# 1,330.00 TND
# 1,598.00 TND
# ok
# *****************************************
# *****************************************
# *****************************************
# *****************************************
